# %%
# Import libraries
import numpy as np
import pandas as pd

import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
#credentials

with open('/Users/paula/.secret/yelp_api.json') as file:
    login = json.load(file)
yelp_login = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
#spedify file path and variables for query:
LOCATION = 'Ventura, CA'
TERM = 'coffee'
query_file = f'data/results_for_ventura_coffee'
query_file
# Out:
# 'data/results_for_ventura_coffee'

# %%
#function for creating files

def json_create_file(JSON_FILE, delete_if_exists= False):
    
    file_exists = os.path.isfile(JSON_FILE)
    
    if file_exists == True:
        if delete_if_exists==True:
            print(f"[!] {JSON_FILE} already exists. Deleting previous file...")
            os.remove(JSON_FILE)
        else:
            print(f"[i] {JSON_FILE} already exists.")  
    else:
        print(f"[i] {JSON_FILE} not found. Saving empty list to new file.")
        folder = os.path.dirname(JSON_FILE) # checks for folder
        if len(folder)>0: #creates folder if needed
            os.makedirs(folder,exist_ok=True)
        with open(JSON_FILE,'w') as f: #creates file
            json.dump([],f)

# %%
# Using it

json_create_file(query_file, delete_if_exists=False)
# Out:
# [i] data/results_for_ventura_coffee not found. Saving empty list to new file.

# %%
with open(query_file,'r') as f:
    previous_results = json.load(f)

# %%
n_results = len(previous_results)

print(f'- {n_results} previous results found.')
# Out:
# - 0 previous results found.

# %%
results = yelp_login.search_query(location=LOCATION,
                                term=TERM,
                               offset=n_results)

# %%
#check total and calculate pages

## total results:
total_results = results['total']

## How many per request?
results_per_page = len(results['businesses'])

# total number of pages of results.
n_pages = math.ceil((results['total']-n_results)/ results_per_page)
n_pages
# Out:
# 21

# %%
#Request Loop with progress bar

for i in tqdm_notebook( range(1,n_pages+1)):
    
    ## Read in results in progress file and check the length
    with open(query_file, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    
    if (n_results + results_per_page) > 1000:
        print('Exceeded 1000 api calls. Stopping loop.')
        break
    
    ## use n_results as the OFFSET 
    results = yelp_login.search_query(location=LOCATION,
                                    term=TERM, 
                                    offset=n_results)
    
    
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
    # display(previous_results)
    with open(query_file,'w') as f:
        json.dump(previous_results,f)
    
    time.sleep(.2)
# Out:
#   0%|          | 0/21 [00:00<?, ?it/s]

# %%
#Final DF

final_df = pd.read_json(query_file)
display(final_df.head(), final_df.tail())
# Out:
#                        id                             alias  \
# 0  v0rljG019LUEBWscFd3QSA  prospect-coffee-roasters-ventura
# 1  tVXzQcLwvy49evwF8q2Szg   humblemaker-coffee-co-ventura-7
# 2  hHlVADfvYyzN8XGDVaSjNw     beacon-coffee-company-ventura
# 3  kJ4LP49r_LnoCBzOJdLp4A   tatianas-coffee-and-tea-ventura
# 4  EdhZ2l_wuhxvCFoMnMrwSA        singing-sun-coffee-ventura
#
#                        name  \
# 0  Prospect Coffee Roasters
# 1    Humblemaker Coffee Co.
# 2     Beacon Coffee Company
# 3  Tatiana's Coffee and Tea
# 4        Singing Sun Coffee
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/-8dNBe...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/7caFL8...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/qTya7A...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/UUua83...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/PLVS9f...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/prospect-coffee-roast...           284
# 1  https://www.yelp.com/biz/humblemaker-coffee-co...            47
# 2  https://www.yelp.com/biz/beacon-coffee-company...           260
# 3  https://www.yelp.com/biz/tatianas-coffee-and-t...           472
# 4  https://www.yelp.com/biz/singing-sun-coffee-ve...            92
#
#                                           categories  rating  \
# 0  [{'alias': 'coffeeroasteries', 'title': 'Coffe...     4.5
# 1     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 2     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 3  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
# 4     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 34.2797234, 'longitude': -119.285...                  []
# 1    {'latitude': 34.28045, 'longitude': -119.29578}  [pickup, delivery]
# 2  {'latitude': 34.2443544757629, 'longitude': -1...                  []
# 3  {'latitude': 34.2753877, 'longitude': -119.263...          [delivery]
# 4    {'latitude': 34.27796, 'longitude': -119.27135}          [delivery]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '92 S Laurel St', 'address2': Non...
# 1    $$  {'address1': '324 E Main St', 'address2': 'Ste...  +18056283219
# 2     $  {'address1': '5777 Olivas Park Dr', 'address2'...
# 3    $$  {'address1': '2470 E Main St', 'address2': Non...  +18059017620
# 4    $$  {'address1': '1930 E Main St', 'address2': Non...
#
#     display_phone     distance
# 0                  4929.700179
# 1  (805) 628-3219  5877.736872
# 2                  3246.926080
# 3  (805) 901-7620  2867.309808
# 4                  3673.101744
#                          id                           alias  \
# 411  91DKVY0ljt0b9gGoZbjFHQ      ralphs-grocery-camarillo-2
# 412  FRb1Yj0GS971p_KpyZYadQ                dennys-camarillo
# 413  bMgauTlniS7o8vM6HYttOw                  ihop-camarillo
# 414  9Okx6DWQSaoxPtKBr-YRIQ  vallarta-supermarkets-oxnard-3
# 415  _otwHgGA1ow-crjgnMdQ5A                vons-camarillo-2
#
#                       name                                          image_url  \
# 411         Ralphs Grocery  https://s3-media3.fl.yelpcdn.com/bphoto/ZVDWrN...
# 412                Denny's  https://s3-media3.fl.yelpcdn.com/bphoto/OaVInM...
# 413                   IHOP  https://s3-media2.fl.yelpcdn.com/bphoto/anAYOW...
# 414  Vallarta Supermarkets  https://s3-media1.fl.yelpcdn.com/bphoto/O-a_Zj...
# 415                   Vons  https://s3-media1.fl.yelpcdn.com/bphoto/FmK572...
#
#      is_closed                                                url  \
# 411      False  https://www.yelp.com/biz/ralphs-grocery-camari...
# 412      False  https://www.yelp.com/biz/dennys-camarillo?adju...
# 413      False  https://www.yelp.com/biz/ihop-camarillo?adjust...
# 414      False  https://www.yelp.com/biz/vallarta-supermarkets...
# 415      False  https://www.yelp.com/biz/vons-camarillo-2?adju...
#
#      review_count                                         categories  rating  \
# 411            85         [{'alias': 'grocery', 'title': 'Grocery'}]     3.5
# 412           154  [{'alias': 'breakfast_brunch', 'title': 'Break...     2.0
# 413            96  [{'alias': 'breakfast_brunch', 'title': 'Break...     3.5
# 414            69         [{'alias': 'grocery', 'title': 'Grocery'}]     3.0
# 415            63         [{'alias': 'grocery', 'title': 'Grocery'}]     2.5
#
#                                            coordinates        transactions  \
# 411  {'latitude': 34.2234948781155, 'longitude': -1...                  []
# 412  {'latitude': 34.2181152436497, 'longitude': -1...  [delivery, pickup]
# 413  {'latitude': 34.2187918, 'longitude': -119.04987}  [delivery, pickup]
# 414  {'latitude': 34.190659, 'longitude': -119.178235}  [delivery, pickup]
# 415  {'latitude': 34.2248473, 'longitude': -119.037...                  []
#
#     price                                           location         phone  \
# 411    $$  {'address1': '674 Las Posas Rd', 'address2': '...  +18053881781
# 412     $  {'address1': '1659 E Daily Dr', 'address2': ''...  +18054844137
# 413    $$  {'address1': '1620 E Daily Dr', 'address2': ''...  +18054841346
# 414     $  {'address1': '1050 S A St', 'address2': '', 'a...  +18052401400
# 415    $$  {'address1': '820 Arneill Rd', 'address2': '',...  +18054828802
#
#       display_phone      distance
# 411  (805) 388-1781  15957.200255
# 412  (805) 484-4137  17919.539035
# 413  (805) 484-1346  17746.452260
# 414  (805) 240-1400   9768.389697
# 415  (805) 482-8802  18707.122056

# %%
final_df = final_df.drop_duplicates(subset='id')
final_df.duplicated(subset='id').sum()
# Out:
# 0

# %%
final_df.to_csv('Data/final_results_Ventura_coffee.csv.gz', compression='gzip',index=False)
